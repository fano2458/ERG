# %%
import pandas as pd

# %%
df = pd.read_csv(r'training\output_03-10.csv', index_col=[0], parse_dates=[0])

# %% [markdown]
# # Pressure sensors:
#
# '1023-115-201-GAZO-0001-GCP1/G_BB02_PIA03/FurOverpressure.U'
#
# '1023-115-201-GAZO-0002-GCP2/G_BB02_PIA03/FurOverpressure.U'
#
# '1023-115-201-GAZO-0001-GCP1/G_GB01_PIA03/OutPrs1GasColr.U'
#
# '1023-115-201-GAZO-0002-GCP2/G_GB01_PIA03/OutPrs1GasColr.U'

# %%
begin_date = '11-Mar-2024'
end_date = '17-Mar-2024'

overpressure_1 = df['1023-115-201-GAZO-0001-GCP1/G_BB02_PIA03/FurOverpressure.U']
overpressure_1.loc[(overpressure_1.index > begin_date) & (overpressure_1.index <= end_date)].plot()
# Out:
# <Axes: xlabel='time'>

# %%
overpressure_1.plot(kind='hist', bins=500)
# Out:
# <Axes: ylabel='Frequency'>

# %%
overpressure_2 = df['1023-115-201-GAZO-0002-GCP2/G_BB02_PIA03/FurOverpressure.U']
overpressure_2.loc[(overpressure_2.index > begin_date) & (overpressure_2.index <= end_date)].plot()
# Out:
# <Axes: xlabel='time'>

# %%
overpressure_2.plot(kind='hist', bins=500)
# Out:
# <Axes: ylabel='Frequency'>

# %%
overpressure_3 = df['1023-115-201-GAZO-0001-GCP1/G_GB01_PIA03/OutPrs1GasColr.U']
overpressure_3.loc[(overpressure_3.index > begin_date) & (overpressure_3.index <= end_date)].plot()
# Out:
# <Axes: xlabel='time'>

# %%
overpressure_3.plot(kind='hist', bins=500)
# Out:
# <Axes: ylabel='Frequency'>

# %%
overpressure_4 = df['1023-115-201-GAZO-0002-GCP2/G_GB01_PIA03/OutPrs1GasColr.U']
overpressure_4.loc[(overpressure_4.index > begin_date) & (overpressure_4.index <= end_date)].plot()
# Out:
# <Axes: xlabel='time'>

# %%
overpressure_4.plot(kind='hist', bins=500)
# Out:
# <Axes: ylabel='Frequency'>
